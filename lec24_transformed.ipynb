ury marquis"],[350.0,155.0,4502,"buick lesabre custom"],[350.0,160.0,4456,"oldsmobile delta 88 royale"],[400.0,190.0,4422,"chrysler newport royal"],[70.0,97.0,2330,"mazda rx2 coupe"],[304.0,150.0,3892,"amc matador (sw)"],[307.0,130.0,4098,"chevrolet chevelle concours (sw)"],[302.0,140.0,4294,"ford gran torino (sw)"],[318.0,150.0,4077,"plymouth satellite custom (sw)"],[121.0,112.0,2933,"volvo 145e (sw)"],[121.0,76.0,2511,"volkswagen 411 (sw)"],[120.0,87.0,2979,"peugeot 504 (sw)"],[96.0,69.0,2189,"renault 12 (sw)"],[122.0,86.0,2395,"ford pinto (sw)"],[97.0,92.0,2288,"datsun 510 (sw)"],[120.0,97.0,2506,"toyouta corona mark ii (sw)"],[98.0,80.0,2164,"dodge colt (sw)"],[97.0,88.0,2100,"toyota corolla 1600 (sw)"],[350.0,175.0,4100,"buick century 350"],[304.0,150.0,3672,"amc matador"],[350.0,145.0,3988,"chevrolet malibu"],[302.0,137.0,4042,"ford gran torino"],[318.0,150.0,3777,"dodge coronet custom"],[429.0,198.0,4952,"mercu ...

# %% [markdown]
# # SVD

# %%
# Seed for reproducibility
np.random.seed(42)

# Generate 100 rows of random data for width and height
width = np.random.randint(1, 10, size=100)
height = np.random.randint(1, 10, size=100)

# Calculate area and perimeter
area = width * height
perimeter = 2 * (width + height)

# Create a DataFrame
df = pd.DataFrame({
    'width': width,
    'height': height,
    'area': area,
    'perimeter': perimeter
})

# Display the DataFrame
print(df)

# Optionally save t
rectangle = df
# Out:
#     width  height  area  perimeter
# 0       7       3    21         20
# 1       4       5    20         18
# 2       8       3    24         22
# 3       5       1     5         12
# 4       7       5    35         24
# ..    ...     ...   ...        ...
# 95      3       1     3          8
# 96      8       8    64         32
# 97      6       7    42         26
# 98      3       2     6         10
# 99      1       8     8         18
#
# [100 rows x 4 columns]

# %%
px.scatter_3d(rectangle, x="width", y="height", z="area",
              width=800, height=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c71edcd-d5bf-41f4-8980-a0bf4cfa988f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c71edcd-d5bf-41f4-8980-a0bf4cfa988f")) {                    Plotly.newPlot(                        "4c71edcd-d5bf-41f4-8980-a0bf4cfa988f",                        [{"hovertemplate":"width=%{x}\u003cbr\u003eheight=%{y}\u003cbr\u003earea=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[7,4,8,5,7,3,7,8,5,4,8,8,3,6,5,2,8,6,2,5,1,6,9,1,3,7,4,9,3,5,3,7,5,9,7,2,4,9,2,9,5,2,4,7,8,3,1,4,2,8,4,2,6,6,4,6,2,2,4,8,7,9,8,5,2,5,8,9,9,1,9,7,9,8,1,8,8,3,1,8,3,3,1,5,7,9,7,9,8,2,1,7,7,8,5,3,8,6,3,1],"y":[3,5,3,1,5,7,7,9,3,7,1,4,4,5,7,7,4,7,3,6,2,9,5,6,4,7,9,7,1,1,9,9,4,9,3,7,6,8,9,5,1,3,8,6,8,9,4,1,1,4,7,2,3,1,5,1,8,1,1,2,2,6,7,5,1,1,3,2,5,6,7,4,7,8,1,6,8,5,4,2,6,6,1,9,6,3,4,4,3,3,3,4,7,4,9,1,8,7,2,8],"z":[21,20,24,5,35,21,49,72,15,28,8,32,12,30,35,14,32,42,6,30,2,54,45,6,12,49,36,63,3,5,27,63,20,81,21,14,24,72,18,45,5,6,32,42,64,27,4,4,2,32,28,4,18,6,20,6,16,2,4,16,14,54,56,25,2,5,24,18,45,6,63,28,63,64,1,48,64,15,4,16,18,18,1,45,42,27,28,36,24,6,3,28,49,32,45,3,64,42,6,8],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar" ...

# %%
X = rectangle - np.mean(rectangle, axis = 0)
X
# Out:
#     width  height   area  perimeter
# 0    1.68   -1.82  -5.69      -0.28
# 1   -1.32    0.18  -6.69      -2.28
# 2    2.68   -1.82  -2.69       1.72
# 3   -0.32   -3.82 -21.69      -8.28
# 4    1.68    0.18   8.31       3.72
# ..    ...     ...    ...        ...
# 95  -2.32   -3.82 -23.69     -12.28
# 96   2.68    3.18  37.31      11.72
# 97   0.68    2.18  15.31       5.72
# 98  -2.32   -2.82 -20.69     -10.28
# 99  -4.32    3.18 -18.69      -2.28
#
# [100 rows x 4 columns]

# %%
U, S, Vt = np.linalg.svd(X, full_matrices = False)

# %%
print("Shape of U", U.shape)
print("Shape of S", S.shape)
print("Shape of Vt", Vt.shape)
# Out:
# Shape of U (100, 4)
# Shape of S (4,)
# Shape of Vt (4, 4)

# %%
S
# Out:
# array([2.19021118e+02, 2.51026227e+01, 2.37839919e+01, 7.07267933e-15])

# %%
np.isclose(S[3], 0)
# Out:
# True

# %%
S.round(5)
# Out:
# array([219.02112,  25.10262,  23.78399,   0.     ])

# %%
Sm = np.diag(S)
Sm
# Out:
# array([[2.19021118e+02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.51026227e+01, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.37839919e+01, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.07267933e-15]])

# %%
pd.DataFrame(U).head(5)
# Out:
#           0         1         2         3
# 0  0.024642 -0.110201 -0.056535 -0.743871
# 1  0.032460  0.011529  0.044111 -0.628156
# 2  0.008334 -0.153658 -0.066202 -0.010045
# 3  0.106845 -0.040768 -0.094409  0.016026
# 4 -0.041912 -0.040482 -0.028199  0.004047

# %%
pd.DataFrame(Vt)
# Out:
#           0         1         2         3
# 0 -0.086898 -0.087549 -0.929008 -0.348896
# 1 -0.521422  0.133187  0.327831 -0.776471
# 2 -0.525474  0.728115 -0.171672  0.405282
# 3  0.666667  0.666667  0.000000 -0.333333

# %%
Vt.shape
# Out:
# (4, 4)

# %%
display(pd.DataFrame(U @ Sm @ Vt).head(5))
display(pd.DataFrame(X).head(5))
# Out:
#       0     1      2     3
# 0  1.68 -1.82  -5.69 -0.28
# 1 -1.32  0.18  -6.69 -2.28
# 2  2.68 -1.82  -2.69  1.72
# 3 -0.32 -3.82 -21.69 -8.28
# 4  1.68  0.18   8.31  3.72
#    width  height   area  perimeter
# 0   1.68   -1.82  -5.69      -0.28
# 1  -1.32    0.18  -6.69      -2.28
# 2   2.68   -1.82  -2.69       1.72
# 3  -0.32   -3.82 -21.69      -8.28
# 4   1.68    0.18   8.31       3.72

# %%
X = rectangle - np.mean(rectangle, axis = 0)
X.head(10)
# Out:
#    width  height   area  perimeter
# 0   1.68   -1.82  -5.69      -0.28
# 1  -1.32    0.18  -6.69      -2.28
# 2   2.68   -1.82  -2.69       1.72
# 3  -0.32   -3.82 -21.69      -8.28
# 4   1.68    0.18   8.31       3.72
# 5  -2.32    2.18  -5.69      -0.28
# 6   1.68    2.18  22.31       7.72
# 7   2.68    4.18  45.31      13.72
# 8  -0.32   -1.82 -11.69      -4.28
# 9  -1.32    2.18   1.31       1.72

# %%
Xstd = X / np.std(X, axis = 0)

# %%
U, S, Vt = np.linalg.svd(X, full_matrices = False)

# %%
pd.DataFrame(np.diag(S))
# Out:
#             0          1          2             3
# 0  219.021118   0.000000   0.000000  0.000000e+00
# 1    0.000000  25.102623   0.000000  0.000000e+00
# 2    0.000000   0.000000  23.783992  0.000000e+00
# 3    0.000000   0.000000   0.000000  7.072679e-15

# %%
pd.DataFrame(np.round(S**2 / X.shape[0], 2))
# Out:
#         0
# 0  479.70
# 1    6.30
# 2    5.66
# 3    0.00

# %%
U, S, Vt = np.linalg.svd(Xstd, full_matrices = False)

# %%
pd.DataFrame(np.round(S**2 / X.shape[0], 2))
# Out:
#       0
# 0  3.08
# 1  0.85
# 2  0.07
# 3  0.00

# %%
Z = U[:, :2] @ np.diag(S[:2])
pd.DataFrame(Z).head()
# Out:
#           0         1
# 0  0.202043 -0.948314
# 1  0.530966  0.404602
# 2 -0.185823 -1.219145
# 3  1.867004 -0.947964
# 4 -0.796291 -0.405225

# %%
Z = Xstd.to_numpy() @ Vt.T[:,:2]
pd.DataFrame(Z).head()
# Out:
#           0         1
# 0  0.202043 -0.948314
# 1  0.530966  0.404602
# 2 -0.185823 -1.219145
# 3  1.867004 -0.947964
# 4 -0.796291 -0.405225

# %%
px.scatter(x=Z[:, 0], y=Z[:, 1])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d105a473-1597-461d-9efc-c8158eb9ebdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d105a473-1597-461d-9efc-c8158eb9ebdf")) {                    Plotly.newPlot(                        "d105a473-1597-461d-9efc-c8158eb9ebdf",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.20204286888331946,0.5309658052387808,-0.18582344807883416,1.8670040438061786,-0.7962907250503372,0.19326116060503962,-1.7946243189839939,-3.344481809282461,0.9777755028076267,-0.3037102092922187,0.8670626723223747,-0.7122665082794386,1.3634463927002103,-0.35387188162063116,-0.800681579189477,0.6902325305022979,-0.7122665082794386,-1.2976529490867352,2.1413744536940875,-0.3560673086902011,2.8647499882204124,-2.2414340165528395,-1.6811284119097492,1.5227131179637274,1.3634463927002103,-1.7946243189839939,-1.138386223823218,-2.78856705877851,2.5336316247953814,1.8670040438061786,-0.5868623274584075,-2.7929579129176503,0.5331612323083508,-3.896005705647272,0.20204286888331946,0.6902325305022979,0.11362779797328103,-3.3422863822128908,-0.03533843109359683,-1.6811284119097492,1.8670040438061786,2.1413744536940875,-0.7210482165577184,-1.2954575220171654,-2.8180387490818566,-0.5868623274584075,2.19373155309207,2.20031783430078,2.8669454152899827,-0.7122665082794386,-0.3037102092922187,2.5041599344920353,0.589909185845473,1.533690253311577,0.5309658052387808,1.533690253311577,0.3274470497043506,2.8669454152899827,2.20031783430078,0.34061961212177033,0.7012096658501477,-2.23484773534413,-2.291595688881252,0.08854696180907486,2.8669454152899827,1.8670040438061786,-0.18582344807883416,-0.019970441606607187,-1.6811284119097492,1.5227131179637274,-2.78856705877851,-0.29712392808350885,-2.78856705877851,-2.8180387490818566,3.2002592057845836,-1.7651526286806476,-2.8180387490818566,0.9733846486684867,2.19373155309207,0.34061961212177033,0.5833229046367632,0.5833229046367632,3.2002592057845836,-1.6899101201880289,-1.2954575220171654,-0.5736897650409878,-0.29712392808350885,-1.1274090884753685,-0.18582344807883416,2.1413744536940875,2.529240770656241,-0.29712392808350885,-1.7946243189839939,-0.7122665082794386,-1.6899101201880289,2.5336316247953814,-2.8180387490818566,-1.2976529490867352,2.1435698807636574,0.851694682835385],"xaxis":"x","y":[-0.9483138084389888,0.40460218543678894,-1.2191446024840273,-0.9479642887616442,-0.4052248266821154,1.2140796778783487,0.13786415507475802,0.4127877128028042,-0.4066522203489117,0.9450257971774509,-1.7631220409129713,-0.9471558832695555,0.4047769452754613,-0.13528248930914727,0.6759719164765533,1.4831335585792462,-0.9471558832695555,0.40691803577565566,0.40584016178620397,0.4053158822701871,0.4077918349690172,0.9491185608604586,-0.9451095014280517,1.4833083184179185,0.4047769452754613,0.13786415507475802,1.4854494089181132,-0.40024360632703737,-0.4045257873274262,-0.9479642887616442,1.7536148329469403,0.6809531368316314,-0.1359961861425454,0.1446222887739769,-0.9483138084389888,1.4831335585792462,0.6748139913071199,-0.1278106587765303,2.0217802569757675,-0.9451095014280517,-0.9479642887616442,0.40584016178620397,1.2152376030477818,-0.13368033580367866,0.14079899358833223,1.7536148329469403,0.9455500766934679,-0.6762450380445353,-0.13280653661031724,-0.9471558832695555,0.9450257971774509,0.13651681258794332,-0.6774830143939503,-1.2196835394787533,0.40460218543678894,-1.2196835394787533,1.752456907777507,-0.13280653661031724,-0.6762450380445353,-1.4911333216984992,-1.2198582993174256,-0.6726765538775445,-0.13118972562613965,0.1346598480638 ...

# %%
pca = PCA(2)
pd.DataFrame(pca.fit_transform(rectangle)).head(5)
# Out:
#            0         1
# 0  -5.397096  2.766336
# 1  -7.109492 -0.289415
# 2  -1.825383  3.857206
# 3 -23.401282  1.023394
# 4   9.179695  1.016211

# %%
pd.DataFrame(pca.fit_transform(X)).head(5)
# Out:
#            0         1
# 0  -5.397096  2.766336
# 1  -7.109492 -0.289415
# 2  -1.825383  3.857206
# 3 -23.401282  1.023394
# 4   9.179695  1.016211

# %%
pd.DataFrame(pca.fit_transform(Xstd)).head(5)
# Out:
#           0         1
# 0 -0.202043 -0.948314
# 1 -0.530966  0.404602
# 2  0.185823 -1.219145
# 3 -1.867004 -0.947964
# 4  0.796291 -0.405225

# %%
pd.DataFrame(np.cov(Z.T))
# Out:
#               0             1
# 0  3.114190e+00  2.572106e-16
# 1  2.572106e-16  8.555627e-01

# %%
rectangle.head()
# Out:
#    width  height  area  perimeter
# 0      7       3    21         20
# 1      4       5    20         18
# 2      8       3    24         22
# 3      5       1     5         12
# 4      7       5    35         24

# %%
k = 2
U, S, Vt = np.linalg.svd(Xstd, full_matrices = False)
scaling = np.diag(np.std(X, axis = 0))
# scaling = np.eye(X.shape[1])
Z = U[:,:k] @ np.diag(S[:k])

rectangle_hat = pd.DataFrame(
    (Z @ Vt[:k, :]) @ scaling + np.mean(rectangle, axis = 0).to_numpy(),
    columns = rectangle.columns)

display(rectangle_hat.head(3))

fig = px.scatter_3d(rectangle, x="width", y="height", z="area",
                    width=800, height=800)
fig.add_scatter3d(x=rectangle_hat["width"], y=rectangle_hat["height"], z=rectangle_hat["area"],
                  mode="markers", name = "approximation")
# Out:
#       width    height       area  perimeter
# 0  6.860274  2.852990  24.228986  19.426528
# 1  3.967272  4.965565  20.756333  17.865674
# 2  7.802330  2.792025  28.568040  21.188711
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7ff6b740-1704-4fcf-83ef-d1e13608449c" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ff6b740-1704-4fcf-83ef-d1e13608449c")) {                    Plotly.newPlot(                        "7ff6b740-1704-4fcf-83ef-d1e13608449c",                        [{"hovertemplate":"width=%{x}\u003cbr\u003eheight=%{y}\u003cbr\u003earea=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[7,4,8,5,7,3,7,8,5,4,8,8,3,6,5,2,8,6,2,5,1,6,9,1,3,7,4,9,3,5,3,7,5,9,7,2,4,9,2,9,5,2,4,7,8,3,1,4,2,8,4,2,6,6,4,6,2,2,4,8,7,9,8,5,2,5,8,9,9,1,9,7,9,8,1,8,8,3,1,8,3,3,1,5,7,9,7,9,8,2,1,7,7,8,5,3,8,6,3,1],"y":[3,5,3,1,5,7,7,9,3,7,1,4,4,5,7,7,4,7,3,6,2,9,5,6,4,7,9,7,1,1,9,9,4,9,3,7,6,8,9,5,1,3,8,6,8,9,4,1,1,4,7,2,3,1,5,1,8,1,1,2,2,6,7,5,1,1,3,2,5,6,7,4,7,8,1,6,8,5,4,2,6,6,1,9,6,3,4,4,3,3,3,4,7,4,9,1,8,7,2,8],"z":[21,20,24,5,35,21,49,72,15,28,8,32,12,30,35,14,32,42,6,30,2,54,45,6,12,49,36,63,3,5,27,63,20,81,21,14,24,72,18,45,5,6,32,42,64,27,4,4,2,32,28,4,18,6,20,6,16,2,4,16,14,54,56,25,2,5,24,18,45,6,63,28,63,64,1,48,64,15,4,16,18,18,1,45,42,27,28,36,24,6,3,28,49,32,45,3,64,42,6,8],"type":"scatter3d"},{"mode":"markers","name":"approximation","x":[6.860274281898425,3.9672717025456827,7.802330326336504,4.983171005059276,6.97291673786442,2.8387299440660905,7.085559193830415,8.319734596238991,4.976162193022269,3.9004372565071717,7.629862236369007,7.888564371320252,3.0287200641261065,5.971035059424841,4.962144568948252,1.7770226316250097,7.888564371320252,6.023851881389334,2.149994059708034,4.965648974966757,1.3310936892914622,6.076668703353827,8.976680094743578,0.8384709932054362,3.0287200641261065,7.085559193830415,3.833602810468663,9.208973818712577,3.2187101841861225,4.983171005059276,2.71206986402608,7.198201649796409,4.972657787003764,9.441267542681576,6.860274281898425,1.7770226316250097,3.9338544795264268,9.325120680697076,1.5905369175834974,8.976680094743578,4.983171005059276,2.149994059708034,3.8670200334879175,7.029237965847417,8.233500551255243,2.71206986402608,1.0847823412484496,4.100940594622701,2.336479773749546,7.888564371320252,3.9004372565071717,2.2432369167287893,5.918218237460347,5.865401415495854,3.9672717025456814,5.865401415495854,1.6837797746042535,2.336479773749546,4.100940594622701,7.716096281352755,6.803953053915428,9.092826956728079,8.147266506271496,4.969153380985261,2.336479773749546,4.983171005059276,7.802330326336504,8.628239508790083,8.976680094743578,0.8384709932054362,9.208973818712577,6.9165955098814225,9.208973818712577,8.233500551255243,1.4542493633129698,8.061032461287748,8.233500551255243,2.9653900241061013,1.0847823412484496,7.716096281352755,2.9020599840860957,2.9020599840860957,1.4542493633129698,4.955135756911245,7.029237965847417,8.744386370774581,6.9165955098814225,8.860533232759082,7.802330326336504,2.149994059708034,1.2079380152699555,6.9165955098814225,7.085559193830415,7.888564371320252,4.955135756911245,3.2187101841861225,8.233500551255243,6.023851881389334,3.1553801441661173,0.5921596451624227],"y":[2.8529898840068997,4.965565460171634,2.7920251042656066,0.9822936497883328,4.971504791228708,6.830322363333128,7.090019698450513,9.336403496211986,2.9749194434894948,6.895246697112474,0.6105656402834798,3.8827548362566704,4.030217343062347,4.969525014209683,6.96017103089182,6.765398029553781,3.8827548362566704,7.0250953646711665,3.157813782713384,5.963858134041239,2.348354779124741,9.08066571513265,4.975464345266758,5.830049912444496,4.030217343062347,7.090019698450513,8.824927934053314,7.219868366009206,1.2301123227915673,0.9822936497883328,8.697059043513647,9.208534605672318,3.97123234034007 ...

# %% [markdown]
# ΣΣ is a little different in NumPy. Since the only useful values in the diagonal matrix ΣΣ are the singular values on the diagonal axis, only those values are returned and they are stored in an array.
# Our rectangle_data has a rank of 33, so we should have 3 non-zero singular values, sorted from largest to smallest.

# %% [markdown]
# Hmm, looks like are four diagonal entries are not zero. What happened?
# It turns out there were some numerical rounding errors, but the last value is so small (10−1510−15) that it's practically 00.

# %% [markdown]
# If we want the diagonal elements:

# %% [markdown]
# Examining U:

# %% [markdown]
# Finally, V⊤V⊤:

# %% [markdown]
# To check that this SVD is a valid decomposition, we can reverse it.

# %% [markdown]
# PCA with SVD¶Step 1: Center the Data Matrix XX¶

# %% [markdown]
# In some situations where the units are on different scales it is useful to normalize the data before performing SVD.
# This can be done by dividing each column by its standard deviation.

# %% [markdown]
# Step 2: Get the SVD of centered XX¶

# %% [markdown]
# Examining the singular values:

# %% [markdown]
# Computing the contribution to the total variance:

# %% [markdown]
# Much of the variance is in the first dimension.  This is likely because the area is much larger than the other dimensions. Let's examine the standardized version.

# %% [markdown]
# Now we see that most of the variance is in the first two dimensions which makes sense since rectangles are largely described by two numbers.

# %% [markdown]
# Step 3 Computing Approximations to the Data¶Let's try to approximate this data in two dimensions

# %% [markdown]
# Using Z=U∗SZ=U∗S¶

# %% [markdown]
# Comparing to scikit learn

# %% [markdown]
# Also notice that the covariance of the transformed diagonalized.

# %% [markdown]
# Lower Rank Approximation of X¶

# %% [markdown]
# Lower Rank Approximation of X¶

# %% [markdown]
# Let's now try to recover X from our approximation:
